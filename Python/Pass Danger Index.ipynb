# %%
import pandas as pd
from scipy.stats import hmean

# Load the Excel file into a DataFrame
file_path = "/Users/marclambertes/Downloads/DB2425/WSL.xlsx"
df = pd.read_excel(file_path)

# Drop rows with NaN values in the specified columns
df.dropna(subset=['Smart passes per 90', 'Deep completions per 90', 'Key passes per 90', 'Shot assists per 90'], inplace=True)

# Filter out rows where any of the metrics are zero
df = df[(df['Smart passes per 90'] != 0) & 
        (df['Deep completions per 90'] != 0) & 
        (df['Key passes per 90'] != 0) & 
        (df['Shot assists per 90'] != 0)]

# Calculate harmonic mean for each player
df['Harmonic Mean'] = hmean(df[['Smart passes per 90', 'Deep completions per 90', 'Key passes per 90', 'Shot assists per 90']], axis=1)

# Print player names along with their specific harmonic mean
for index, row in df.iterrows():
    print(f"Player: {row['Player']}, Harmonic Mean: {row['Harmonic Mean']}")
    
df.to_excel("/Users/marclambertes/Downloads/PDI WSL.xlsx", index=False)
# Out:
# Player: A. Neville, Harmonic Mean: 0.37158110882956885
# Player: R. Ueki, Harmonic Mean: 0.5100186949167631
# Player: D. Janssen, Harmonic Mean: 0.23621867881548975
# Player: M. Bright, Harmonic Mean: 0.17742857142857144
# Player: K. Casparij, Harmonic Mean: 0.3101827676240209
# Player: A. Denton, Harmonic Mean: 0.144
# Player: Y. Hasegawa, Harmonic Mean: 0.3493963402875294
# Player: G. Clinton, Harmonic Mean: 0.4122352941176471
# Player: T. Hinds, Harmonic Mean: 0.18797848533626477
# Player: K. Gorry, Harmonic Mean: 0.5774424568759111
# Player: Vicky Losada, Harmonic Mean: 0.35704697986577183
# Player: C. Wheeler, Harmonic Mean: 0.16684330052990157
# Player: S. Nüsken, Harmonic Mean: 0.49408873720136526
# Player: K. McCabe, Harmonic Mean: 0.5869363232033804
# Player: D. Spence, Harmonic Mean: 0.610190114068441
# Player: J. Carabalí, Harmonic Mean: 0.25161290322580643
# Player: J. Nobbs, Harmonic Mean: 0.3632432432432432
# Player: E. Summanen, Harmonic Mean: 0.26666666666666666
# Player: A. Potter, Harmonic Mean: 0.22057650565146486
# Player: G. Reiten, Harmonic Mean: 0.5404241078219599
# Player: K. Stengel, Harmonic Mean: 0.2591339052972252
# Player: V. Asseyi, Harmonic Mean: 0.34849765794584714
# Player: P. Pattinson, Harmonic Mean: 0.23690587138862998
# Player: N. Parris, Harmonic Mean: 0.37169526930165875
# Player: E. Fox, Harmonic Mean: 0.3421090909090909
# Player: M. Cato, Harmonic Mean: 0.24
# Player: A. Blanchard, Harmonic Mean: 0.49378599331480805
# Player: J. Rytting Kaneryd, Harmonic Mean: 0.5650438318431236
# Player: Y. Momiki, Harmonic Mean: 0.31473771856786015
# Player: L. Bronze, Harmonic Mean: 0.30008438459304576
# Player: K. Snoeijs, Harmonic Mean: 0.22122905027932957
# Player: M. Gejl, Harmonic Mean: 0.3118993872944212
# Player: J. Cayman, Harmonic Mean: 0.29870330038532417
# Player: E. Terland, Harmonic Mean: 0.19070220399794977
# Player: Mariona Caldentey, Harmonic Mean: 0.662893812459737
# Player: B. England, Harmonic Mean: 0.29382161600349016
# Player: M. Höbinger, Harmonic Mean: 0.209368285345939
# Player: J. Park, Harmonic Mean: 0.5269198312236287
# Player: F. Kirby, Harmonic Mean: 0.6356329171603026
# Player: K. Shaw, Harmonic Mean: 0.29940348459494043
# Player: M. Olislagers, Harmonic Mean: 0.2921739130434783
# Player: C. Foord, Harmonic Mean: 0.2792436426863725
# Player: C. Holland, Harmonic Mean: 0.22618441161487518
# Player: S. Piubel, Harmonic Mean: 0.5030296066275798
# Player: J. Roord, Harmonic Mean: 0.3831643346739931
# Player: O. Siren, Harmonic Mean: 0.20023047883965828
# Player: J. Riviere, Harmonic Mean: 0.3157894736842105
# Player: K. Hanson, Harmonic Mean: 0.5932595557648537
# Player: M. Thomas, Harmonic Mean: 0.3081416229036083
# Player: M. Ramírez, Harmonic Mean: 0.3353627722295753
# Player: F. Maanum, Harmonic Mean: 0.9134470550370132
# Player: C. Bott, Harmonic Mean: 0.21677419354838715
# Player: Laia Aleixandri, Harmonic Mean: 0.3054545454545455
# Player: L. Wälti, Harmonic Mean: 0.2961140289535939
# Player: M. Fowler, Harmonic Mean: 0.4631944444444444
# Player: B. Mead, Harmonic Mean: 0.6351384238389421
# Player: L. Hemp, Harmonic Mean: 0.5197017647374349
# Player: L. Staniforth, Harmonic Mean: 0.36754986636036313
# Player: M. Goodwin, Harmonic Mean: 0.24629688325409405
# Player: Li Mengwen, Harmonic Mean: 0.21106382978723404
# Player: T. Payne, Harmonic Mean: 0.19344827586206897
# Player: M. Pavi, Harmonic Mean: 0.5138743222824638
# Player: M. Hamano, Harmonic Mean: 0.34324983373974727
# Player: K. Dali, Harmonic Mean: 0.8696087230161467
# Player: S. Chossenotte, Harmonic Mean: 0.4601094168315679
# Player: Laia Codina, Harmonic Mean: 0.2391666666666667
# Player: M. Enderby, Harmonic Mean: 0.29464330067614186
# Player: Gabi Nunes, Harmonic Mean: 0.29464330067614186
# Player: P. Bremer, Harmonic Mean: 0.3866212566059894
# Player: Maite Oroz, Harmonic Mean: 0.5623422512315882
# Player: A. Weerden, Harmonic Mean: 0.4673126738942723
# Player: A. Leon, Harmonic Mean: 0.3910535052994509
# Player: M. Agyemang, Harmonic Mean: 0.5944001474695931
# Player: J. Canković, Harmonic Mean: 0.5700475841249808
# Player: C. Macário, Harmonic Mean: 1.0665169253589022
# Player: V. Miedema, Harmonic Mean: 0.8497619917221899
# Player: C. Kelly, Harmonic Mean: 0.8867006442927203
# Player: L. James, Harmonic Mean: 0.7341176470588235
