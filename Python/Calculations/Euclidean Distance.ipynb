# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances

# Load data
df = pd.read_excel(r'/Users/marclambertes/Downloads/Wyscout/Premier League 2023-2024.xlsx', index_col='Player')
df = df[df['Minutes played'] >= 500]

# Optional filtering
# df = df[df['League'] == 'Eredivisie']
# df = df[(df['League'] != 'Belarus') & (df['League'] != 'Russian Super League') & (df['League'] != 'Ukraine')]
# df = df[(df['Team'] != 'Chelsea')]

# Drop columns
cols_to_drop = ['Minutes played', 'Matches played', 'Birth country',
                'Passport country', 'Height', 'Weight']
df = df.drop(columns=cols_to_drop)

# Handle missing values
if df.isna().values.any():
    df = df.fillna(0)

# Separate numeric vs. categorical columns
num_cols = [col for col in df.columns if df[col].dtype in ['int64', 'float64']]
df = df[['Team', 'Team within selected timeframe', 'Position'] + num_cols]

# Scale numeric features
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# Calculate Euclidean distance matrix
eucl_dist = pairwise_distances(df[num_cols], metric='euclidean')

def get_similar_players(player_name, top_n=300):
    """
    Returns a list of tuples: (PlayerName, Team, Position, Distance)
    Sorted from smallest to largest distance.
    """
    index = df.index.get_loc(player_name)
    
    # Get distances from 'player_name' to every other player
    dist_scores = list(enumerate(eucl_dist[index]))
    
    # Sort by ascending distance (most similar first)
    dist_scores = sorted(dist_scores, key=lambda x: x[1])
    
    # Slice out the top_n (skipping index 0, which is the player themself)
    top_scores = dist_scores[1:top_n + 1]
    
    # Build the list of (player, team, position, distance)
    similar_players = [
        (df.index[i], 
         df.iloc[i]['Team within selected timeframe'],
         df.iloc[i]['Position'], 
         dist
        ) 
        for i, dist in top_scores
    ]
    return similar_players

# Prompt user for player name
player_name = input("Enter a player name: ")
similar_players = get_similar_players(player_name)

# Convert Euclidean distance to a 0-100 “similarity” scale
# Formula: similarity = 100 * (1 - distance / max_distance)
# so that the largest distance -> 0% similarity, and the smallest distance -> ~100%.
max_distance = max(similar_players, key=lambda x: x[3])[3]
similar_players = [
    (
        player, 
        team, 
        position, 
        100 * (1 - (dist / max_distance))  # scale to 0–100
    )
    for (player, team, position, dist) in similar_players
]

# Print similar players
print(f"Players similar to {player_name}:")
for player, team, position, similarity_score in similar_players:
    print(f"Player: {player}")
    print(f"Team: {team}")
    print(f"Position: {position}")
    print(f"Similarity Score: {similarity_score:.2f}%\n")

# Write similar players to Excel
output_filename = r'/Users/marclambertes/Python/similar players.xlsx'
similar_players_df = pd.DataFrame(
    similar_players, 
    columns=['Player', 'Team', 'Position', 'Similarity Score']
)
similar_players_df.to_excel(output_filename, index=False)
print(f"Similar players saved to {output_filename}")
# Out:
# Enter a player name: Mohamed Salah
# Players similar to Mohamed Salah:
# Player: C. Palmer
# Team: Chelsea
# Position: AMF, RAMF
# Similarity Score: 55.91%
#
# Player: Son Heung-Min
# Team: Tottenham Hotspur
# Position: CF, LAMF
# Similarity Score: 54.71%
#
# Player: João Pedro
# Team: Brighton
# Position: CF, AMF
# Similarity Score: 49.40%
#
# Player: B. Saka
# Team: Arsenal
# Position: RWF, RW
# Similarity Score: 48.14%
#
# Player: D. Núñez
# Team: Liverpool
# Position: CF
# Similarity Score: 45.17%
#
# Player: B. Mbeumo
# Team: Brentford
# Position: RWF, CF
# Similarity Score: 44.06%
#
# Player: L. Bailey
# Team: Aston Villa
# Position: RW, RAMF
# Similarity Score: 42.22%
#
# Player: L. Trossard
# Team: Arsenal
# Position: LWF, CF, LW
# Similarity Score: 41.40%
#
# Player: J. Álvarez
# Team: Manchester City
# Position: CF, AMF
# Similarity Score: 40.47%
#
# Player: M. Ødegaard
# Team: Arsenal
# Position: RCMF
# Similarity Score: 40.39%
#
# Player: Bruno Fernandes
# Team: Manchester United
# Position: AMF, CF, LCMF
# Similarity Score: 40.30%
#
# Player: A. Isak
# Team: Newcastle United
# Position: CF
# Similarity Score: 39.52%
#
# Player: O. Watkins
# Team: Aston Villa
# Position: CF
# Similarity Score: 38.69%
#
# Player: Matheus Cunha
# Team: Wolverhampton Wanderers
# Position: CF, AMF, LWF
# Similarity Score: 38.63%
#
# Player: L. Díaz
# Team: Liverpool
# Position: LWF
# Similarity Score: 38.52%
#
# Player: A. Gordon
# Team: Newcastle United
# Position: LWF, LW, CF
# Similarity Score: 37.72%
#
# Player: D. Kulusevski
# Team: Tottenham Hotspur
# Position: RAMF, AMF
# Similarity Score: 37.37%
#
# Player: D. Solanke
# Team: Bournemouth
# Position: CF
# Similarity Score: 36.51%
#
# Player: M. Diaby
# Team: Aston Villa
# Position: CF, AMF
# Similarity Score: 35.99%
#
# Player: B. Johnson
# Team: Tottenham Hotspur
# Position: RAMF, RWF, LAMF
# Similarity Score: 35.98%
#
# Player: P. Foden
# Team: Manchester City
# Position: AMF, RAMF, RW
# Similarity Score: 35.55%
#
# Player: N. Jackson
# Team: Chelsea
# Position: CF
# Similarity Score: 35.04%
#
# Player: J. Bowen
# Team: West Ham United
# Position: CF, RAMF, RW
# Similarity Score: 34.95%
#
# Player: Willian
# Team: Fulham
# Position: LAMF, LW, LWF
# Similarity Score: 34.25%
#
# Player: C. Gakpo
# Team: Liverpool
# Position: CF, LWF, LCMF
# Similarity Score: 33.89%
#
# Player: K. Havertz
# Team: Arsenal
# Position: LCMF, CF
# Similarity Score: 33.84%
#
# Player: Pablo Sarabia
# Team: Wolverhampton Wanderers
# Position: AMF, RWF, CF
# Similarity Score: 33.14%
#
# Player: Richarlison
# Team: Tottenham Hotspur
# Position: CF, LAMF
# Similarity Score: 33.09%
#
# Player: A. Iwobi
# Team: Fulham
# Position: RAMF, LAMF, AMF
# Similarity Score: 33.01%
#
# Player: M. Rashford
# Team: Manchester United
# Position: LAMF, CF, LW
# Similarity Score: 32.63%
#
# Player: J. Mateta
# Team: Crystal Palace
# Position: CF
# Similarity Score: 32.63%
#
# Player: R. Sterling
# Team: Chelsea
# Position: LAMF, RAMF, LW
# Similarity Score: 32.27%
#
# Player: Gabriel Jesus
# Team: Arsenal
# Position: CF, LWF
# Similarity Score: 32.16%
#
# Player: E. Haaland
# Team: Manchester City
# Position: CF
# Similarity Score: 32.14%
#
# Player: A. Elanga
# Team: Nottingham Forest
# Position: RAMF, LAMF, CF
# Similarity Score: 31.90%
#
# Player: Hwang Hee-Chan
# Team: Wolverhampton Wanderers
# Position: CF
# Similarity Score: 31.88%
#
# Player: H. Barnes
# Team: Newcastle United
# Position: LWF, LW
# Similarity Score: 31.58%
#
# Player: Diogo Jota
# Team: Liverpool
# Position: CF, LWF, RWF
# Similarity Score: 31.37%
#
# Player: M. Gibbs-White
# Team: Nottingham Forest
# Position: AMF, RW, CF
# Similarity Score: 31.26%
#
# Player: A. Semenyo
# Team: Bournemouth
# Position: RAMF, RW, LAMF
# Similarity Score: 30.79%
#
# Player: B. De Cordova-Reid
# Team: Fulham
# Position: RAMF, LW, RW
# Similarity Score: 30.45%
#
# Player: E. Eze
# Team: Crystal Palace
# Position: AMF, LWF, LW
# Similarity Score: 30.34%
#
# Player: C. Wilson
# Team: Newcastle United
# Position: CF
# Similarity Score: 29.91%
#
# Player: Bernardo Silva
# Team: Manchester City
# Position: RAMF, RW, LDMF
# Similarity Score: 29.76%
#
# Player: Gabriel Martinelli
# Team: Arsenal
# Position: LWF, LW
# Similarity Score: 29.51%
#
# Player: S. Adingra
# Team: Brighton
# Position: RW, LAMF, RAMF
# Similarity Score: 29.47%
#
# Player: A. Doucouré
# Team: Everton
# Position: AMF, CF, RCMF
# Similarity Score: 29.19%
#
# Player: H. Elliott
# Team: Liverpool
# Position: RCMF, RWF
# Similarity Score: 29.06%
#
# Player: Y. Wissa
# Team: Brentford
# Position: CF, LWF
# Similarity Score: 28.89%
#
# Player: N. Maupay
# Team: Brentford
# Position: CF
# Similarity Score: 28.72%
#
# Player: A. Garnacho
# Team: Manchester United
# Position: LAMF, LW, RAMF
# Similarity Score: 28.56%
#
# Player: M. Olise
# Team: Crystal Palace
# Position: RWF, RW, AMF
# Similarity Score: 28.23%
#
# Player: B. Brereton Díaz
# Team: Sheffield United
# Position: CF, LW
# Similarity Score: 28.21%
#
# Player: C. Hudson-Odoi
# Team: Nottingham Forest
# Position: LAMF, LW, LWF
# Similarity Score: 28.08%
#
# Player: Douglas Luiz
# Team: Aston Villa
# Position: LCMF, LDMF
# Similarity Score: 27.93%
#
# Player: M. Mudryk
# Team: Chelsea
# Position: LAMF, LW
# Similarity Score: 27.73%
#
# Player: C. Morris
# Team: Luton Town
# Position: CF
# Similarity Score: 27.49%
#
# Player: J. Kluivert
# Team: Bournemouth
# Position: AMF, LW, LAMF
# Similarity Score: 27.40%
#
# Player: J. Maddison
# Team: Tottenham Hotspur
# Position: AMF
# Similarity Score: 27.08%
#
# Player: K. Lewis-Potter
# Team: Brentford
# Position: LWF, LWB, LB
# Similarity Score: 26.87%
#
# Player: H. Wilson
# Team: Fulham
# Position: RAMF, RW
# Similarity Score: 26.82%
#
# Player: Andreas Pereira
# Team: Fulham
# Position: AMF
# Similarity Score: 26.63%
#
# Player: J. Harrison
# Team: Everton
# Position: RW, AMF
# Similarity Score: 26.55%
#
# Player: M. Tavernier
# Team: Bournemouth
# Position: LAMF, RAMF, LW
# Similarity Score: 26.24%
#
# Player: D. McNeil
# Team: Everton
# Position: LW, LAMF
# Similarity Score: 26.15%
#
# Player: J. Murphy
# Team: Newcastle United
# Position: RWF, RW
# Similarity Score: 25.87%
#
# Player: J. McAtee
# Team: Sheffield United
# Position: RW, CF, LCMF
# Similarity Score: 25.79%
#
# Player: N. Madueke
# Team: Chelsea
# Position: RAMF, RW
# Similarity Score: 25.74%
#
# Player: K. Mitoma
# Team: Brighton
# Position: LW, LAMF
# Similarity Score: 25.69%
#
# Player: Bruno Guimarães
# Team: Newcastle United
# Position: DMF, LCMF
# Similarity Score: 25.64%
#
# Player: R. Højlund
# Team: Manchester United
# Position: CF
# Similarity Score: 24.43%
#
# Player: Z. Amdouni
# Team: Burnley
# Position: CF
# Similarity Score: 24.43%
#
# Player: S. Benrahma
# Team: West Ham United
# Position: LAMF, LW
# Similarity Score: 24.17%
#
# Player: D. Szoboszlai
# Team: Liverpool
# Position: RCMF, LCMF
# Similarity Score: 24.12%
#
# Player: J. McGinn
# Team: Aston Villa
# Position: LW, RCMF, RW
# Similarity Score: 23.96%
#
# Player: Lucas Paquetà
# Team: West Ham United
# Position: LAMF, AMF, LW
# Similarity Score: 23.94%
#
# Player: Antony
# Team: Manchester United
# Position: RAMF, RW
# Similarity Score: 23.45%
#
# Player: C. Ogbene
# Team: Luton Town
# Position: RWB, LW, LWF
# Similarity Score: 22.85%
#
# Player: Pedro Neto
# Team: Wolverhampton Wanderers
# Position: RW, CF, LW
# Similarity Score: 22.68%
#
# Player: O. Édouard
# Team: Crystal Palace
# Position: CF, LWF
# Similarity Score: 22.60%
#
# Player: M. Almirón
# Team: Newcastle United
# Position: RWF, RW
# Similarity Score: 22.52%
#
# Player: R. Jiménez
# Team: Fulham
# Position: CF
# Similarity Score: 22.50%
#
# Player: S. Longstaff
# Team: Newcastle United
# Position: RCMF, LCMF
# Similarity Score: 22.45%
#
# Player: E. Fernández
# Team: Chelsea
# Position: LDMF, LCMF
# Similarity Score: 22.42%
#
# Player: J. Gudmunds­son
# Team: Burnley
# Position: RW, RAMF
# Similarity Score: 21.87%
#
# Player: Rodrigo Muniz
# Team: Fulham
# Position: CF
# Similarity Score: 21.59%
#
# Player: G. Hamer
# Team: Sheffield United
# Position: RCMF, LCMF, LW
# Similarity Score: 21.52%
#
# Player: M. Kudus
# Team: West Ham United
# Position: RAMF, LAMF, RW
# Similarity Score: 21.31%
#
# Player: M. Antonio
# Team: West Ham United
# Position: CF
# Similarity Score: 21.21%
#
# Player: D. Welbeck
# Team: Brighton
# Position: CF
# Similarity Score: 20.22%
#
# Player: R. Barkley
# Team: Luton Town
# Position: LCMF, RCMF
# Similarity Score: 19.73%
#
# Player: J. Grealish
# Team: Manchester City
# Position: LAMF, LW
# Similarity Score: 19.63%
#
# Player: S. March
# Team: Brighton
# Position: RW, LB, RAMF
# Similarity Score: 19.49%
#
# Player: C. Nkunku
# Team: Chelsea
# Position: CF, AMF, LAMF
# Similarity Score: 19.49%
#
# Player: C. Wood
# Team: Nottingham Forest
# Position: CF
# Similarity Score: 19.48%
#
# Player: J. Ayew
# Team: Crystal Palace
# Position: RAMF, RWF, RW
# Similarity Score: 19.47%
#
# Player: P. Groß
# Team: Brighton
# Position: LCMF, RCMF, RDMF
# Similarity Score: 18.73%
#
# Player: J. Ramsey
# Team: Aston Villa
# Position: LW, LAMF
# Similarity Score: 18.62%
#
# Player: J. Bruun Larsen
# Team: Burnley
# Position: LW, RW
# Similarity Score: 18.28%
#
# Player: M. Rogers
# Team: Aston Villa
# Position: LW, AMF
# Similarity Score: 18.27%
#
# Player: Pedro Porro
# Team: Tottenham Hotspur
# Position: RB
# Similarity Score: 18.26%
#
# Player: R. Christie
# Team: Bournemouth
# Position: LDMF, RDMF, LCMF
# Similarity Score: 18.25%
#
# Player: D. Fofana
# Team: Burnley
# Position: CF
# Similarity Score: 18.11%
#
# Player: L. Foster
# Team: Burnley
# Position: CF
# Similarity Score: 18.09%
#
# Player: Ansu Fati
# Team: Brighton
# Position: CF, AMF, LW
# Similarity Score: 18.08%
#
# Player: J. Ward-Prowse
# Team: West Ham United
# Position: AMF, LCMF, LDMF
# Similarity Score: 18.01%
#
# Player: A. Townsend
# Team: Luton Town
# Position: RW, RWF, AMF
# Similarity Score: 18.00%
#
# Player: D. Calvert-Lewin
# Team: Everton
# Position: CF
# Similarity Score: 17.72%
#
# Player: E. Nketiah
# Team: Arsenal
# Position: CF
# Similarity Score: 17.63%
#
# Player: Y. Tielemans
# Team: Aston Villa
# Position: RCMF, CF, AMF
# Similarity Score: 17.63%
#
# Player: I. Toney
# Team: Brentford
# Position: CF
# Similarity Score: 17.36%
#
# Player: T. Chong
# Team: Luton Town
# Position: LWF, LW, LCMF
# Similarity Score: 17.17%
#
# Player: L. Sinisterra
# Team: Bournemouth
# Position: LAMF
# Similarity Score: 17.10%
#
# Player: A. Mac Allister
# Team: Liverpool
# Position: DMF, RCMF, LCMF
# Similarity Score: 17.03%
#
# Player: T. Werner
# Team: Tottenham Hotspur
# Position: LAMF, LW
# Similarity Score: 17.01%
#
# Player: D. Rice
# Team: Arsenal
# Position: DMF, LCMF
# Similarity Score: 16.88%
#
# Player: S. McTominay
# Team: Manchester United
# Position: RDMF, AMF
# Similarity Score: 16.64%
#
# Player: P. Sarr
# Team: Tottenham Hotspur
# Position: RDMF, RCMF
# Similarity Score: 16.40%
#
# Player: T. Awoniyi
# Team: Nottingham Forest
# Position: CF
# Similarity Score: 16.37%
#
# Player: R. Gravenberch
# Team: Liverpool
# Position: LCMF, RCMF
# Similarity Score: 16.24%
#
# Player: J. Schlupp
# Team: Crystal Palace
# Position: LAMF, LW, AMF
# Similarity Score: 16.07%
#
# Player: C. Eriksen
# Team: Manchester United
# Position: LDMF, LCMF
# Similarity Score: 16.03%
#
# Player: Pablo Fornals
# Team: West Ham United
# Position: RW, LW, LAMF
# Similarity Score: 15.94%
#
# Player: B. White
# Team: Arsenal
# Position: RB
# Similarity Score: 15.64%
#
# Player: M. Jensen
# Team: Brentford
# Position: RCMF, LCMF
# Similarity Score: 15.62%
#
# Player: D. Origi
# Team: Nottingham Forest
# Position: RAMF, CF
# Similarity Score: 15.42%
#
# Player: M. Damsgaard
# Team: Brentford
# Position: RCMF, LCMF
# Similarity Score: 15.37%
#
# Player: J. Bellegarde
# Team: Wolverhampton Wanderers
# Position: CF, AMF, RW
# Similarity Score: 15.36%
#
# Player: C. Archer
# Team: Sheffield United
# Position: CF
# Similarity Score: 15.27%
#
# Player: M. Cash
# Team: Aston Villa
# Position: RB, RW
# Similarity Score: 15.00%
#
# Player: J. Clark
# Team: Luton Town
# Position: RCMF, RWF, LCMF
# Similarity Score: 14.40%
#
# Player: Matheus Nunes
# Team: Manchester City
# Position: RDMF, LDMF, LW
# Similarity Score: 14.33%
#
# Player: P. Billing
# Team: Bournemouth
# Position: AMF, LCMF, RCMF
# Similarity Score: 14.26%
#
# Player: J. Rodriguez
# Team: Burnley
# Position: CF
# Similarity Score: 14.19%
#
# Player: C. Gallagher
# Team: Chelsea
# Position: AMF, LDMF, RCMF
# Similarity Score: 14.08%
#
# Player: C. Jones
# Team: Liverpool
# Position: LCMF
# Similarity Score: 13.99%
#
# Player: D. Ings
# Team: West Ham United
# Position: CF, AMF
# Similarity Score: 13.97%
#
# Player: A. Lallana
# Team: Brighton
# Position: AMF, CF
# Similarity Score: 13.86%
#
# Player: Adama Traoré
# Team: Fulham
# Position: RAMF, LW, RW
# Similarity Score: 13.85%
#
# Player: A. Danjuma
# Team: Everton
# Position: LW, CF, RW
# Similarity Score: 13.83%
#
# Player: V. Janelt
# Team: Brentford
# Position: LCMF, DMF, LB
# Similarity Score: 13.79%
#
# Player: E. Adebayo
# Team: Luton Town
# Position: CF
# Similarity Score: 13.65%
#
# Player: Beto
# Team: Everton
# Position: CF
# Similarity Score: 13.65%
#
# Player: R. Aït-Nouri
# Team: Wolverhampton Wanderers
# Position: LWB, LB, LW
# Similarity Score: 13.65%
#
# Player: E. Ferguson
# Team: Brighton
# Position: CF
# Similarity Score: 13.43%
#
# Player: C. Bradley
# Team: Liverpool
# Position: RB
# Similarity Score: 13.35%
#
# Player: J. Gvardiol
# Team: Manchester City
# Position: LB
# Similarity Score: 13.24%
#
# Player: M. Roerslev
# Team: Brentford
# Position: RWB, RB
# Similarity Score: 13.10%
#
# Player: P. Estupiñán
# Team: Brighton
# Position: LB, LWB
# Similarity Score: 13.09%
#
# Player: Joelinton
# Team: Newcastle United
# Position: LCMF
# Similarity Score: 13.01%
#
# Player: K. De Bruyne
# Team: Manchester City
# Position: AMF, RCMF
# Similarity Score: 12.93%
#
# Player: Álex Moreno
# Team: Aston Villa
# Position: LB
# Similarity Score: 12.69%
#
# Player: T. Lamptey
# Team: Brighton
# Position: RB, LB, LWB
# Similarity Score: 12.68%
#
# Player: L. Miley
# Team: Newcastle United
# Position: RCMF, DMF, LCMF
# Similarity Score: 12.62%
#
# Player: A. Scott
# Team: Bournemouth
# Position: AMF, RDMF, RCMF
# Similarity Score: 12.47%
#
# Player: G. Lo Celso
# Team: Tottenham Hotspur
# Position: AMF, LCMF, RCMF
# Similarity Score: 12.31%
#
# Player: C. Woodrow
# Team: Luton Town
# Position: CF, LWF, RWF
# Similarity Score: 12.25%
#
# Player: V. Mykolenko
# Team: Everton
# Position: LB
# Similarity Score: 12.22%
#
# Player: O. Aina
# Team: Nottingham Forest
# Position: LB, RB
# Similarity Score: 12.01%
#
# Player: L. Digne
# Team: Aston Villa
# Position: LB
# Similarity Score: 11.98%
#
# Player: Vitinho
# Team: Burnley
# Position: RB, LB, RW
# Similarity Score: 11.97%
#
# Player: Danilo
# Team: Nottingham Forest
# Position: LDMF, LCMF
# Similarity Score: 11.95%
#
# Player: T. Mitchell
# Team: Crystal Palace
# Position: LB, LWB
# Similarity Score: 11.65%
#
# Player: T. Souček
# Team: West Ham United
# Position: RDMF, RCMF, AMF
# Similarity Score: 11.57%
#
# Player: N. Zaniolo
# Team: Aston Villa
# Position: LW, LAMF, CF
# Similarity Score: 11.49%
#
# Player: T. Castagne
# Team: Fulham
# Position: RB
# Similarity Score: 11.49%
#
# Player: J. Brownhill
# Team: Burnley
# Position: LCMF
# Similarity Score: 11.46%
#
# Player: A. Robertson
# Team: Liverpool
# Position: LB
# Similarity Score: 11.45%
#
# Player: Diogo Dalot
# Team: Manchester United
# Position: RB, LB
# Similarity Score: 11.40%
#
# Player: J. Garner
# Team: Everton
# Position: RCMF, LCMF, RW
# Similarity Score: 11.33%
#
# Player: R. Bentancur
# Team: Tottenham Hotspur
# Position: LDMF, DMF, RDMF
# Similarity Score: 11.16%
#
# Player: R. Lewis
# Team: Manchester City
# Position: RB, RDMF, RCMF
# Similarity Score: 11.10%
#
# Player: O. Zinchenko
# Team: Arsenal
# Position: LB
# Similarity Score: 10.93%
#
# Player: J. Doku
# Team: Manchester City
# Position: LAMF, LW, LWF
# Similarity Score: 10.92%
#
# Player: T. Cairney
# Team: Fulham
# Position: LDMF, LCMF, AMF
# Similarity Score: 10.78%
#
# Player: T. Tomiyasu
# Team: Arsenal
# Position: LB, RB
# Similarity Score: 10.73%
#
# Player: J. Durán
# Team: Aston Villa
# Position: CF
# Similarity Score: 10.71%
#
# Player: B. Chilwell
# Team: Chelsea
# Position: LWB, LB
# Similarity Score: 10.68%
#
# Player: V. Coufal
# Team: West Ham United
# Position: RB
# Similarity Score: 10.68%
#
# Player: J. Milner
# Team: Brighton
# Position: RB, LB, LCMF
# Similarity Score: 10.44%
#
# Player: J. Hinshelwood
# Team: Brighton
# Position: RB, RWB, LB
# Similarity Score: 10.44%
#
# Player: M. Lemina
# Team: Wolverhampton Wanderers
# Position: RCMF, LCMF, DMF
# Similarity Score: 10.18%
#
# Player: O. McBurnie
# Team: Sheffield United
# Position: CF
# Similarity Score: 9.99%
#
# Player: K. Walker
# Team: Manchester City
# Position: RB
# Similarity Score: 9.92%
#
# Player: J. Bogle
# Team: Sheffield United
# Position: RB, RWB
# Similarity Score: 9.91%
#
# Player: C. Nørgaard
# Team: Brentford
# Position: DMF
# Similarity Score: 9.82%
#
# Player: A. Doughty
# Team: Luton Town
# Position: LWB, LB
# Similarity Score: 9.66%
#
# Player: M. Aarons
# Team: Bournemouth
# Position: RB
# Similarity Score: 9.61%
#
# Player: J. Gomez
# Team: Liverpool
# Position: LB, RB
# Similarity Score: 9.58%
#
# Player: J. Lerma
# Team: Crystal Palace
# Position: LCMF, LDMF, RCMF
# Similarity Score: 9.40%
#
# Player: T. Alexander-Arnold
# Team: Liverpool
# Position: RB
# Similarity Score: 9.03%
#
# Player: A. Robinson
# Team: Fulham
# Position: LB
# Similarity Score: 8.74%
#
# Player: S. Aurier
# Team: Nottingham Forest
# Position: RB, RWB
# Similarity Score: 8.53%
#
# Player: B. Osborn
# Team: Sheffield United
# Position: LB, LCMF, LWB
# Similarity Score: 8.46%
#
# Player: M. Trésor
# Team: Burnley
# Position: LW, RW
# Similarity Score: 8.46%
#
# Player: P. Mpanzu
# Team: Luton Town
# Position: RCMF, LCMF
# Similarity Score: 8.13%
#
# Player: Emerson Palmieri
# Team: West Ham United
# Position: LB
# Similarity Score: 8.12%
#
# Player: J. Kiwior
# Team: Arsenal
# Position: LB, LCB
# Similarity Score: 8.09%
#
# Player: Nélson Semedo
# Team: Wolverhampton Wanderers
# Position: RWB, RB
# Similarity Score: 7.93%
#
# Player: N. Patterson
# Team: Everton
# Position: RB
# Similarity Score: 7.86%
#
# Player: M. Doherty
# Team: Wolverhampton Wanderers
# Position: LWB, RWB
# Similarity Score: 7.85%
#
# Player: H. Reed
# Team: Fulham
# Position: RDMF, RCMF
# Similarity Score: 7.75%
#
# Player: Y. Yarmoliuk
# Team: Brentford
# Position: RCMF, LCMF
# Similarity Score: 7.49%
#
# Player: K. Mainoo
# Team: Manchester United
# Position: RDMF, LDMF, LCMF
# Similarity Score: 7.38%
#
# Player: Y. Larouci
# Team: Sheffield United
# Position: LWB, LB
# Similarity Score: 7.32%
#
# Player: C. Taylor
# Team: Burnley
# Position: LB
# Similarity Score: 7.25%
#
# Player: T. Livramento
# Team: Newcastle United
# Position: LB, RB
# Similarity Score: 7.22%
#
# Player: H. Toffolo
# Team: Nottingham Forest
# Position: LB
# Similarity Score: 7.16%
#
# Player: F. Onyeka
# Team: Brentford
# Position: RCMF
# Similarity Score: 7.14%
#
# Player: M. Gusto
# Team: Chelsea
# Position: RB, RWB
# Similarity Score: 7.09%
#
# Player: G. Baldock
# Team: Sheffield United
# Position: RCB, RWB, RB
# Similarity Score: 7.08%
#
# Player: A. Martial
# Team: Manchester United
# Position: CF
# Similarity Score: 6.97%
#
# Player: N. Domínguez
# Team: Nottingham Forest
# Position: LDMF, RDMF, LCMF
# Similarity Score: 6.91%
#
# Player: K. Ajer
# Team: Brentford
# Position: CB, RB, RCB
# Similarity Score: 6.75%
#
# Player: S. Ghoddos
# Team: Brentford
# Position: LB, RB
# Similarity Score: 6.64%
#
# Player: A. Onana
# Team: Everton
# Position: LCMF, RCMF
# Similarity Score: 6.57%
#
# Player: D. Muñoz
# Team: Crystal Palace
# Position: RWB, RB
# Similarity Score: 6.46%
#
# Player: Rodri
# Team: Manchester City
# Position: RDMF, DMF, LDMF
# Similarity Score: 6.41%
#
# Player: G. Montiel
# Team: Nottingham Forest
# Position: RB, RWB
# Similarity Score: 6.28%
#
# Player: L. Cook
# Team: Bournemouth
# Position: LDMF, RDMF, RCMF
# Similarity Score: 6.27%
#
# Player: L. Assignon
# Team: Burnley
# Position: RB
# Similarity Score: 6.19%
#
# Player: Sergio Reguilón
# Team: Brentford
# Position: LB, LWB
# Similarity Score: 6.12%
#
# Player: J. Brown
# Team: Luton Town
# Position: RWF, RW, LWF
# Similarity Score: 6.03%
#
# Player: A. Broja
# Team: Fulham
# Position: CF
# Similarity Score: 5.94%
#
# Player: A. Sambi Lokonga
# Team: Luton Town
# Position: RCMF, LCMF
# Similarity Score: 5.90%
#
# Player: F. Schär
# Team: Newcastle United
# Position: RCB, LCB
# Similarity Score: 5.73%
#
# Player: J. Cullen
# Team: Burnley
# Position: RCMF, DMF, LCMF
# Similarity Score: 5.67%
#
# Player: D. Udogie
# Team: Tottenham Hotspur
# Position: LB
# Similarity Score: 5.59%
#
# Player: B. Godfrey
# Team: Everton
# Position: RB, LB
# Similarity Score: 5.49%
#
# Player: S. Berge
# Team: Burnley
# Position: RCMF, LCMF
# Similarity Score: 5.46%
#
# Player: M. Kovačić
# Team: Manchester City
# Position: LDMF, LCMF, RDMF
# Similarity Score: 5.23%
#
# Player: B. Johnson
# Team: West Ham United
# Position: RB, RAMF, LAMF
# Similarity Score: 5.21%
#
# Player: A. Smith
# Team: Bournemouth
# Position: RB
# Similarity Score: 5.12%
#
# Player: A. Ben Slimane
# Team: Sheffield United
# Position: RW, LW, RCMF
# Similarity Score: 5.09%
#
# Player: K. Tsimikas
# Team: Liverpool
# Position: LB
# Similarity Score: 4.93%
#
# Player: A. Wan-Bissaka
# Team: Manchester United
# Position: RB, LB
# Similarity Score: 4.86%
#
# Player: J. Andersen
# Team: Crystal Palace
# Position: RCB, CB
# Similarity Score: 4.77%
#
# Player: N. Williams
# Team: Nottingham Forest
# Position: RB
# Similarity Score: 4.58%
#
# Player: I. Kaboré
# Team: Luton Town
# Position: RWB, RB
# Similarity Score: 4.58%
#
# Player: J. Moder
# Team: Brighton
# Position: AMF, CF, RB
# Similarity Score: 4.37%
#
# Player: R. Yates
# Team: Nottingham Forest
# Position: RDMF, RCMF
# Similarity Score: 4.28%
#
# Player: M. Mount
# Team: Manchester United
# Position: LDMF, LCMF, AMF
# Similarity Score: 4.23%
#
# Player: João Gomes
# Team: Wolverhampton Wanderers
# Position: RCMF, LCMF
# Similarity Score: 4.20%
#
# Player: Toti
# Team: Wolverhampton Wanderers
# Position: LCB, LB
# Similarity Score: 4.09%
#
# Player: D. Burn
# Team: Newcastle United
# Position: LB, LCB
# Similarity Score: 4.02%
#
# Player: Pau Torres
# Team: Aston Villa
# Position: LCB
# Similarity Score: 3.89%
#
# Player: K. Tete
# Team: Fulham
# Position: RB
# Similarity Score: 3.83%
#
# Player: E. Krafth
# Team: Newcastle United
# Position: RB, RCB
# Similarity Score: 3.78%
#
# Player: K. Trippier
# Team: Newcastle United
# Position: RB
# Similarity Score: 3.75%
#
# Player: J. Veltman
# Team: Brighton
# Position: RB
# Similarity Score: 3.68%
#
# Player: L. Colwill
# Team: Chelsea
# Position: LB, LCB
# Similarity Score: 3.65%
#
# Player: A. Wharton
# Team: Crystal Palace
# Position: RCMF, LCMF, DMF
# Similarity Score: 3.43%
#
# Player: N. Aké
# Team: Manchester City
# Position: LCB, LB
# Similarity Score: 3.40%
#
# Player: C. Doucouré
# Team: Crystal Palace
# Position: RDMF, RCMF
# Similarity Score: 3.39%
#
# Player: L. Thomas
# Team: Sheffield United
# Position: LWB, LB
# Similarity Score: 3.36%
#
# Player: L. Hall
# Team: Newcastle United
# Position: LB, LCB
# Similarity Score: 3.22%
#
# Player: B. Gilmour
# Team: Brighton
# Position: LDMF, RCMF, LCMF
# Similarity Score: 3.22%
#
# Player: Nuno Tavares
# Team: Nottingham Forest
# Position: LB
# Similarity Score: 3.20%
#
# Player: Hugo Bueno
# Team: Wolverhampton Wanderers
# Position: LWB, LB
# Similarity Score: 2.95%
#
# Player: André Gomes
# Team: Everton
# Position: AMF, LCMF, RCMF
# Similarity Score: 2.82%
#
# Player: Gabriel Magalhaes
# Team: Arsenal
# Position: LCB
# Similarity Score: 2.79%
#
# Player: B. Davies
# Team: Tottenham Hotspur
# Position: LCB, LB
# Similarity Score: 2.34%
#
# Player: E. Konsa
# Team: Aston Villa
# Position: RB, RCB
# Similarity Score: 2.31%
#
# Player: Jorginho
# Team: Arsenal
# Position: DMF, LCMF, RCMF
# Similarity Score: 2.25%
#
# Player: B. Mee
# Team: Brentford
# Position: LCB
# Similarity Score: 2.23%
#
# Player: L. Kelly
# Team: Bournemouth
# Position: LB, LCB
# Similarity Score: 2.07%
#
# Player: W. Hughes
# Team: Crystal Palace
# Position: LCMF, LDMF
# Similarity Score: 2.04%
#
# Player: L. Shaw
# Team: Manchester United
# Position: LB, LCB
# Similarity Score: 1.90%
#
# Player: B. Kamara
# Team: Aston Villa
# Position: RCMF, RDMF
# Similarity Score: 1.85%
#
# Player: D. Hashioka
# Team: Luton Town
# Position: RCB, LCB, RWB
# Similarity Score: 1.83%
#
# Player: M. Keane
# Team: Everton
# Position: RCB, CB
# Similarity Score: 1.79%
#
# Player: A. Ahmedhodžić
# Team: Sheffield United
# Position: RCB, CB
# Similarity Score: 1.67%
#
# Player: S. Lukić
# Team: Fulham
# Position: RDMF, LDMF, RCMF
# Similarity Score: 1.66%
#
# Player: J. Ward
# Team: Crystal Palace
# Position: RB, RCB
# Similarity Score: 1.60%
#
# Player: A. Disasi
# Team: Chelsea
# Position: RCB, RB
# Similarity Score: 1.59%
#
# Player: R. Giles
# Team: Luton Town
# Position: LB, LWB
# Similarity Score: 1.59%
#
# Player: A. Ramsey
# Team: Burnley
# Position: RW, LCMF, LWF
# Similarity Score: 1.56%
#
# Player: M. Jørgensen
# Team: Brentford
# Position: RCB
# Similarity Score: 1.50%
#
# Player: T. Partey
# Team: Arsenal
# Position: DMF, RB, RCMF
# Similarity Score: 1.48%
#
# Player: R. Burke
# Team: Luton Town
# Position: RCB, RB
# Similarity Score: 1.44%
#
# Player: I. Sangaré
# Team: Nottingham Forest
# Position: LDMF, RCMF
# Similarity Score: 1.36%
#
# Player: T. Doyle
# Team: Wolverhampton Wanderers
# Position: LCMF, RCMF, DMF
# Similarity Score: 1.30%
#
# Player: D. O'Shea
# Team: Burnley
# Position: RCB
# Similarity Score: 1.14%
#
# Player: J. Tarkowski
# Team: Everton
# Position: RCB
# Similarity Score: 0.98%
#
# Player: V. Lindelöf
# Team: Manchester United
# Position: LB, LCB, RCB
# Similarity Score: 0.95%
#
# Player: M. Kerkez
# Team: Bournemouth
# Position: LB
# Similarity Score: 0.92%
#
# Player: J. Robinson
# Team: Sheffield United
# Position: LCB, CB
# Similarity Score: 0.86%
#
# Player: M. Kilman
# Team: Wolverhampton Wanderers
# Position: RCB, CB, LCB
# Similarity Score: 0.84%
#
# Player: W. Boly
# Team: Nottingham Forest
# Position: RCB
# Similarity Score: 0.77%
#
# Player: B. Traoré
# Team: Wolverhampton Wanderers
# Position: LCMF, RCMF
# Similarity Score: 0.77%
#
# Player: H. Maguire
# Team: Manchester United
# Position: RCB, LCB
# Similarity Score: 0.77%
#
# Player: M. Caicedo
# Team: Chelsea
# Position: RDMF, DMF, LDMF
# Similarity Score: 0.70%
#
# Player: N. Clyne
# Team: Crystal Palace
# Position: RCB, RB, LB
# Similarity Score: 0.68%
#
# Player: M. Senesi
# Team: Bournemouth
# Position: LCB
# Similarity Score: 0.56%
#
# Player: O. Norwood
# Team: Sheffield United
# Position: DMF, LCMF, RCMF
# Similarity Score: 0.46%
#
# Player: I. Gueye
# Team: Everton
# Position: RCMF, LCMF, DMF
# Similarity Score: 0.45%
#
# Player: C. Roberts
# Team: Burnley
# Position: RB
# Similarity Score: 0.43%
#
# Player: Marc Cucurella
# Team: Chelsea
# Position: LB, RB
# Similarity Score: 0.39%
#
# Player: O. Mangala
# Team: Nottingham Forest
# Position: DMF, LCMF, RDMF
# Similarity Score: 0.32%
#
# Player: K. Zouma
# Team: West Ham United
# Position: RCB, LCB
# Similarity Score: 0.00%
#
# Similar players saved to /Users/marclambertes/Python/similar players.xlsx

# %%
import matplotlib.patheffects as path_effects
import matplotlib.pyplot as plt
from mplsoccer.pitch import VerticalPitch
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib.colors import LinearSegmentedColormap
from scipy.ndimage import gaussian_filter


df = pd.read_excel('/Users/marclambertes/Python/similar players.xlsx')
#df['League'] = df['League'].str.split(' - ').str[0]

#df = df[(df['League'] != 'Armenia')]
#df = df[df['Age'] <= 23]

df = df.rename(columns={'Similarity Score': 'Similarity'})
def ax_logo(team, ax,):
    path = r'/Users/marclambertes/Downloads/Images'
    club_icon = Image.open('%s/%s.png' %(path,team))
    ax.imshow(club_icon)
    ax.axis('off')
    return ax
df['Similarity'] = (df['Similarity']).round(2)



indexdf = df.head(15)[['Player', 'Team', 'Similarity']].reset_index(drop=True)
indexdf_short=indexdf[::-1]

fig = plt.figure(figsize=(7,8), dpi=200)
ax = plt.subplot()

ncols = len(indexdf_short.columns.tolist())+1
nrows = indexdf_short.shape[0]

ax.set_xlim(0, ncols + 1.2)
ax.set_ylim(0, nrows + 1.5)

# lgs = ['J1', 'J2', 'Ekstraklasa', 'J3']
# if lg in lgs:
positions = [0.15, 2.0, 3.8, 5.7]
# else:
#     positions = [0.25, 2.25, 3.75, 4.5, 5.25]
columns = indexdf_short.columns.tolist()

# Add table's main text
for i in range(nrows):
    for j, column in enumerate(columns):
        if 'xG per 90' in column:
            text_label = f'{indexdf_short[column].iloc[i]:,.2f}'
            weight = 'regular'
        else:
            text_label = f'{indexdf_short[column].iloc[i]}'
            weight = 'regular'
        ax.annotate(
            xy=(positions[j], i + .5),
            text = text_label,
            ha='left',
            va='center', color='#4A2E19',
            weight=weight
        )

# Add column names
column_names = columns
for index, c in enumerate(column_names):
        ax.annotate(
            xy=(positions[index], nrows + .25),
            text=column_names[index],
            ha='left',
            va='bottom',
            weight='bold', color='#4A2E19'
        )

# Add dividing lines
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [nrows, nrows], lw=1.5, color='black', marker='', zorder=4)
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [0, 0], lw=1.5, color='black', marker='', zorder=4)
for x in range(1, nrows):
    ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [x, x], lw=1.15, color='gray', ls=':', zorder=3 , marker='')

ax.set_axis_off()

DC_to_FC = ax.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform
# -- Take data coordinates and transform them to normalized figure coordinates
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
# -- Add nation axes
ax_point_1 = DC_to_NFC([2.25, 0.25])
ax_point_2 = DC_to_NFC([2.75, 0.75])
ax_width = abs(ax_point_1[0] - ax_point_2[0])
ax_height = abs(ax_point_1[1] - ax_point_2[1])
for x in range(0, nrows):
    ax_coords = DC_to_NFC([1.5, x + .25])
    flag_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_width, ax_height]
    )
    ax_logo(indexdf_short['Team'].iloc[x], flag_ax,)

fig.text(
    x=0.15, y=.87,
    s='Similar players to Mohamed Salah - Liverpool',
    ha='left',
    va='bottom',
    weight='bold',
    size=14, color='#4A2E19'
)
fig.text(
    x=0.15, y=0.10,
    s='Data as of 27/12/2024 | Data: Wyscout | Created: Marc Lamberts\nEuclidean Distance calculated with z-scores',
    ha='left',
    va='top',
    weight='regular',
    size=8, color='#4A2E19'
)

fig.text(
    x=0.15, y=0.86,
    s='Similar players do reflect playing style and not level of quality/performance',
    ha='left',
    va='top',
    weight='regular',
    size=8, color='#4A2E19'
)

plt.savefig('Similar Players - Mohamed Salah2.png',dpi=750,bbox_inches = 'tight', facecolor='white')
#plt.savefig('Similar Players - Momiki.pdf', dpi=750, bbox_inches='tight', facecolor='white')
