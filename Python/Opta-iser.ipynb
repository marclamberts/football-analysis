# %%
import pandas as pd

#df = pd.read_excel(r"/Users/marclambertes/Python/Barca.xlsx")
df = pd.read_csv("/Users/marclambertes/Python/Matches/Men/Portugal 2024-2025/Porto 4-0 Estoril.csv")

type_cols = [col for col in df.columns if '/qualifierId' in col]

df['endX'] = 0.0
df['endY'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 140:
            endx = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['endX'][i] = endx
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 141:
            endy = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['endY'][i] = endy
        else:
            k +=1

df['Cross'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 2:
            df['Cross'][i] = 1
        else:
            j +=1
           
df['Cutback'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 195:
            df['Cutback'][i] = 1
        else:
            j +=1


df['Corner'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 6:
            df['Corner'][i] = 1
        else:
            j +=1

df['Corner shot'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 25:
            df['Corner shot'][i] = 1
        else:
            j +=1
            
df['Corner 2nd phase'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 25:
            df['Corner 2nd phase'][i] = 1
        else:
            j +=1
           
df['FK'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 5:
            df['FK'][i] = 1
        else:
            j +=1
df['GK'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 124:
            df['GK'][i] = 1
        else:
            j +=1
df['ThrowIn'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 107:
            df['ThrowIn'][i] = 1
        else:
            j +=1

df['Throw-in set piece'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 160:
            df['Throw-in set piece'][i] = 1
        else:
            j +=1

df['Through-ball'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 4:
            df['Through-ball'][i] = 1
        else:
            j +=1

df['LongBall'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 1:
            df['LongBall'][i] = 1
        else:
            j +=1

df['Switch'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 196:
            df['Switch'][i] = 1
        else:
            j +=1
            
df['Assist'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 210:
            df['Assist'][i] = 1
        else:
            j +=1

df['2nd Assist'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 218:
            df['2nd Assist'][i] = 1
        else:
            j +=1

df['Number'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 59:
            df['Number'][i] = 1
        else:
            j +=1
            
df['FromCorner'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 25:
            df['FromCorner'][i] = 1
        else:
            j +=1

df['Jersey number'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 59:
            df['Jersey number'][i] = 1
        else:
            j +=1

df['Keeper throw'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 123:
            df['Keeper throw'][i] = 1
        else:
            j +=1

df['In-swinger'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 223:
            df['In-swinger'][i] = 1
        else:
            j +=1

df['Out-swinger'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 224:
            df['Out-swinger'][i] = 1
        else:
            j +=1

df['Straight'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 225:
            df['Straight'][i] = 1
        else:
            j +=1

df['GoalMouthY'] = 0.0
df['GoalMouthZ'] = 0.0
for i in range(len(df)):            
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 102:
            mouthy = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['GoalMouthY'][i] = mouthy
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 103:
            mouthz = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['GoalMouthZ'][i] = mouthz
        else:
            k +=1

df['isOwnGoal'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 28:
            df['isOwnGoal'][i] = 1
        else:
            j +=1
           
df['pass_angle'] = 0.0
df['pass_length'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 213:
            angle = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df.pass_angle[i] = angle
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 212:
            length = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df.pass_length[i] = length
        else:
            k +=1

### Here's where you can now filter on typeId and player
#df = df[df['typeId']==1]
#df = df[df['playerName']=='Denzel Dumfries']

df.to_excel("Pass.xlsx")
# Out:
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endX'][i] = endx
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endY'][i] = endy
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cross'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cutback'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Corner'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Corner shot'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Corner 2nd phase'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FK'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GK'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ThrowIn'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Through-ball'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LongBall'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Switch'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Assist'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FromCorner'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jersey number'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Keeper throw'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['In-swinger'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Out-swinger'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Straight'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:268: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GoalMouthY'][i] = mouthy
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:276: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GoalMouthZ'][i] = mouthz
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pass_angle[i] = angle
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44741/4068937766.py:308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pass_length[i] = length

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mplsoccer import Pitch

import pandas as pd
import numpy as np
from mplsoccer.pitch import VerticalPitch
import matplotlib.pyplot as plt
from mplsoccer import Pitch


df = pd.read_excel('Pass.xlsx')



df.head()

df['beginning'] = np.sqrt(np.square(105 - df['x']) + np.square(52.5 - df['y']))
df['end'] = np.sqrt(np.square(105 - df['endX']) + np.square(52.5 - df['endY']))


df['progressive'] = [(df['end'][x]) / (df['beginning'][x]) < .75 for x in range(len(df.beginning))]

df = df.loc[df['typeId']==1]
#df = df.loc[df['TeamId']==1113]


#df.loc[df['progressive']==True].reset_index()
            
df.to_excel("Progressive passes.xlsx")

# %%
df.to_excel("Progressive passes.xlsx") 
# preprocess the dataframe so we only have the data we want
# We want to get it down to be only successful passes made by Bruno Penandes
# we can use pandas .loc method to achieve this with a bunch of & statements

#df = df.loc[(df['teamId']==212) & (df['playerId']==85470) & (df['outcomeType/displayName']=='Successful') & (df['type/displayName']=='Pass')]

#Import xT Grid, turn it into an array, and then get how many rows and columns it has
xT = pd.read_csv("xT_grid.csv", header=None)
xT = np.array(xT)
xT_rows, xT_cols = xT.shape
xT

print(xT_rows,xT_cols)

df['x1_bin'] = pd.cut(df['x'], bins=xT_cols, labels=False)
df['y1_bin'] = pd.cut(df['y'], bins=xT_rows, labels=False)
df['x2_bin'] = pd.cut(df['endX'], bins=xT_cols, labels=False)
df['y2_bin'] = pd.cut(df['endY'], bins=xT_rows, labels=False)

df['start_zone_value'] = df[['x1_bin', 'y1_bin']].apply(lambda x: xT[x[1]][x[0]], axis=1)
df['end_zone_value'] = df[['x2_bin', 'y2_bin']].apply(lambda x: xT[x[1]][x[0]], axis=1)

df['xT'] = df['end_zone_value'] - df['start_zone_value']

df.head()

df.to_excel("xT.xlsx")
# Out:
# 8 12

# %%
import pandas as pd

#df = pd.read_excel(r"/Users/marclambertes/Python/Barca.xlsx")
df = pd.read_excel("/Users/marclambertes/Python/Eredivisie 2324.xlsx")

type_cols = [col for col in df.columns if '/qualifierId' in col]

df['endX'] = 0.0
df['endY'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 140:
            endx = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['endX'][i] = endx
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 141:
            endy = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['endY'][i] = endy
        else:
            k +=1

df['FromCorner'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 5:
            df['FromCorner'][i] = 1
        else:
            j +=1


df['In-swinger'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 223:
            df['In-swinger'][i] = 1
        else:
            j +=1

df['Out-swinger'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 224:
            df['Out-swinger'][i] = 1
        else:
            j +=1

df['Straight'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 225:
            df['Straight'][i] = 1
        else:
            j +=1

df['GoalMouthY'] = 0.0
df['GoalMouthZ'] = 0.0
for i in range(len(df)):            
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 102:
            mouthy = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['GoalMouthY'][i] = mouthy
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 103:
            mouthz = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['GoalMouthZ'][i] = mouthz
        else:
            k +=1

df['isOwnGoal'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 28:
            df['isOwnGoal'][i] = 1
        else:
            j +=1
           
df['pass_angle'] = 0.0
df['pass_length'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 213:
            angle = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df.pass_angle[i] = angle
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 212:
            length = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df.pass_length[i] = length
        else:
            k +=1

### Here's where you can now filter on typeId and player
#df = df[df['typeId']==1]
#df = df[df['playerName']=='Denzel Dumfries']

df.to_excel("Pass.xlsx")
# Out:
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endX'][i] = endx
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endY'][i] = endy
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FK'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['In-swinger'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Out-swinger'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Straight'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GoalMouthY'][i] = mouthy
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GoalMouthZ'][i] = mouthz
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isOwnGoal'][i] = 1
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pass_angle[i] = angle
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44403/4034519056.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pass_length[i] = length

# %%
import os
import pandas as pd

# Function to process each file
def process_file(file_path, save_folder):
    # Load the data
    df = pd.read_csv(file_path)
    
    # Processing logic
    type_cols = [col for col in df.columns if '/qualifierId' in col]

    df['endX'] = 0.0
    df['endY'] = 0.0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]  # Fixed indexing issue
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 140:
                endx = df1.loc[:, f'qualifier/{j}/value'].values[0]
                df.at[i, 'endX'] = endx
        for k in range(len(type_cols)):
            col = df1[type_cols[k]].values[0]
            if col == 141:
                endy = df1.loc[:, f'qualifier/{k}/value'].values[0]
                df.at[i, 'endY'] = endy
    
    df['Cross'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 2:
                df.at[i, 'Cross'] = 1
    
    df['Cutback'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 195:
                df.at[i, 'Cutback'] = 1
    
    df['Corner'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 6:
                df.at[i, 'Corner'] = 1

    df['Corner shot'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 25:
                df.at[i, 'Corner shot'] = 1
            
    df['Corner 2nd phase'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 25:
                df.at[i, 'Corner 2nd phase'] = 1
    
    df['FK'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 5:
                df.at[i, 'FK'] = 1
    
    df['GK'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 124:
                df.at[i, 'GK'] = 1
    
    df['ThrowIn'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 107:
                df.at[i, 'ThrowIn'] = 1

    df['Throw-in set piece'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 160:
                df.at[i, 'Throw-in set piece'] = 1

    df['Through-ball'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 4:
                df.at[i, 'Through-ball'] = 1

    df['LongBall'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 1:
                df.at[i, 'LongBall'] = 1

    df['Switch'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 196:
                df.at[i, 'Switch'] = 1
    
    df['Assist'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 210:
                df.at[i, 'Assist'] = 1

    df['2nd Assist'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 218:
                df.at[i, '2nd Assist'] = 1

    df['Number'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 59:
                df.at[i, 'Number'] = 1
    
    df['FromCorner'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 25:
                df.at[i, 'FromCorner'] = 1

    df['Jersey number'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 59:
                df.at[i, 'Jersey number'] = 1

    df['Keeper throw'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 123:
                df.at[i, 'Keeper throw'] = 1

    df['In-swinger'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 223:
                df.at[i, 'In-swinger'] = 1

    df['Out-swinger'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 224:
                df.at[i, 'Out-swinger'] = 1

    df['Straight'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 225:
                df.at[i, 'Straight'] = 1

    df['GoalMouthY'] = 0.0
    df['GoalMouthZ'] = 0.0
    for i in range(len(df)):            
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 102:
                mouthy = df1.loc[:, f'qualifier/{j}/value'].values[0]
                df.at[i, 'GoalMouthY'] = mouthy
        for k in range(len(type_cols)):
            col = df1[type_cols[k]].values[0]
            if col == 103:
                mouthz = df1.loc[:, f'qualifier/{k}/value'].values[0]
                df.at[i, 'GoalMouthZ'] = mouthz

    df['isOwnGoal'] = 0
    for i in range(len(df)):
        df1 = df.iloc[i:i+1, :]
        for j in range(len(type_cols)):
            col = df1[type_cols[j]].values[0]
            if col == 28:
                df.at[i, 'isOwnGoal'] = 1

    

    # Save the processed file
    file_name = os.path.basename(file_path).replace('.csv', '')  # Get the original file name without extension
    save_path = os.path.join(save_folder, f"{file_name} - Pass.xlsx")
    df.to_excel(save_path, index=False)

# Folder paths
input_folder = "/Users/marclambertes/Python/Matches/Men/Eredivisie 2024-2025"
output_folder = "/Users/marclambertes/Python/Matches/Men/Eredivisie 2024-2025/Pass"  # Change this to your desired output folder

# Ensure output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Process each CSV file in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):  # Only process CSV files
        file_path = os.path.join(input_folder, file_name)
        process_file(file_path, output_folder)

print("Processing complete!")
# Out:
# Processing complete!

# %%
import pandas as pd

#df = pd.read_excel(r"/Users/marclambertes/Python/Barca.xlsx")
df = pd.read_excel("/Users/marclambertes/Python/GERII.xlsx")

type_cols = [col for col in df.columns if '/qualifierId' in col]

df['endX'] = 0.0
df['endY'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 140:
            endx = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['endX'][i] = endx
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 141:
            endy = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['endY'][i] = endy
        else:
            k +=1
            



### Here's where you can now filter on typeId and player
#df = df[df['typeId']==1]
#df = df[df['playerName']=='Denzel Dumfries']

df.to_excel("Pass.xlsx")
# Out:
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_75844/802490658.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endX'][i] = endx
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_75844/802490658.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endY'][i] = endy

# %%
import os
import shutil

# Define the source folder containing the CSV files
source_folder = '/Users/marclambertes/Python/Matches/Men/Portugal 2024-2025'

# Define the destination folder to store files with "Porto" in the title
destination_folder = 'Porto'

# Create the destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Iterate through all files in the source folder
for filename in os.listdir(source_folder):
    # Check if the file is a CSV and contains "Porto" in the name
    if filename.endswith('.csv') and 'Porto' in filename:
        # Full path to the source and destination
        source_file = os.path.join(source_folder, filename)
        destination_file = os.path.join(destination_folder, filename)
        
        # Copy the file to the destination folder
        shutil.copy(source_file, destination_file)

print("Files with 'Porto' in the title have been copied successfully.")
# Out:
# Files with 'Porto' in the title have been copied successfully.
