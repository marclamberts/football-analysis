# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch
from matplotlib import patches
from scipy.ndimage import gaussian_filter  # Import gaussian_filter from scipy.ndimage
from matplotlib.colors import LinearSegmentedColormap
import cmasher as cmr

df = pd.read_csv("WSL 2022-2023.csv")
df = df.loc[(df['contestantId']=='dcdnoyf6kzhj46iyfm7xq43fy')].reset_index()
#df = df.loc[(df['playerName']=='L. Williamson')].reset_index()

#df = df.loc[(df['typeId']==8)].reset_index()
df = df.loc[(df['typeId']==1)].reset_index()
            
pitch = Pitch(pitch_type='opta', pad_bottom=0.5, pad_top=5, pitch_color='#242424', line_color='white', line_zorder=2,
                      half=False,
                      goal_type='box',
                      goal_alpha=0.8)
            
fig, ax = pitch.draw()
figsize=(18, 12)

pitch.draw

fig.set_facecolor('#242424')
bin_statistic = pitch.bin_statistic(df.x, df.y, statistic='count', bins=(15, 15))
bin_statistic['statistic'] = gaussian_filter(bin_statistic['statistic'], 1)
pcm = pitch.heatmap(bin_statistic, ax=ax, cmap='inferno', edgecolors='#242424')

#fig_text(s="Chelsea vs Brighton 3-1", x=0.25, y=0.8, fontsize=20, color="white", fontfamily='Andale Mono', ax=ax)

ax.set_title("Brighton and Hove Albion\nHeatmap WSL 2022-2023", fontsize=18, color="w", fontfamily="Andale Mono", fontweight='bold', pad=8)
plt.savefig('Heatmap balltouches BHA1.png', dpi=750, bbox_inches='tight', facecolor='#242424')
# Out:
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_73771/3235124289.py:10: DtypeWarning: Columns (59,64,69,72,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("WSL 2022-2023.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch
from matplotlib import patches
from scipy.ndimage import gaussian_filter  # Import gaussian_filter from scipy.ndimage
from matplotlib.colors import LinearSegmentedColormap
import cmasher as cmr

df = pd.read_csv("WSL 2022-2023.csv")
df = df.loc[(df['contestantId']=='dcdnoyf6kzhj46iyfm7xq43fy')].reset_index()
#df = df.loc[(df['playerName']=='L. Williamson')].reset_index()

#df = df.loc[(df['typeId']==8)].reset_index()
df = df.loc[(df['typeId']==1)].reset_index()

pitch = Pitch(pitch_type='opta', pad_bottom=0.5, pad_top=5, pitch_color='#242424', line_color='white', line_zorder=2,
                      half=False,
                      goal_type='box',
                      goal_alpha=0.8)

fig, ax = pitch.draw()
figsize=(18, 12)   

pitch.draw


#pearl_earring_cmap_100 = LinearSegmentedColormap.from_list("Pearl Earring - 10 colors",
 #                                                      ['#15242e', '#4393c4'], N=100)
el_greco_yellow_cmap_100 = LinearSegmentedColormap.from_list("El Greco Yellow - 100 colors",
                                                             ['#7c2e2a', '#f2dd44'], N=100)

kdeplot = pitch.kdeplot(df.x, df.y, ax=ax, cmap=el_greco_yellow_cmap_100, fill=True, levels=100)        


#fig_text(s="Chelsea vs Brighton 3-1", x=0.25, y=0.8, fontsize=20, color="white", fontfamily='Andale Mono', ax=ax)

ax.set_title("Brighton and Hove Albion\nHeatmap WSL 2022-2023", fontsize=18, color="w", fontfamily="Andale Mono", fontweight='bold', pad=8)
plt.savefig('Heatmap balltouches BHA.png', dpi=750, bbox_inches='tight', facecolor='#242424')
# Out:
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_73771/67289959.py:10: DtypeWarning: Columns (59,64,69,72,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("WSL 2022-2023.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch
from matplotlib import patches
from scipy.ndimage import gaussian_filter  # Import gaussian_filter from scipy.ndimage
from matplotlib.colors import LinearSegmentedColormap
import cmasher as cmr

df = pd.read_excel("/Users/marclambertes/Python/Czechia xT.xlsx")
df = df.loc[(df['contestantId']=='70tnqyqn871jwlk26gtjw7knm')].reset_index()
#df = df.loc[(df['playerName']=='L. Williamson')].reset_index()

#df = df.loc[(df['typeId']==8)].reset_index()
df = df.loc[(df['typeId']==1)].reset_index()

pitch_dark = Pitch(line_color='#cfcfcf', line_zorder=2, pitch_color='#000000')
fig, ax = pitch_dark.draw()
kdeplot_dark = pitch_dark.kdeplot(df.x, df.y, ax=ax, cmap=cmr.ember, fill=True, levels=100)


#fig_text(s="Chelsea vs Brighton 3-1", x=0.25, y=0.8, fontsize=20, color="white", fontfamily='Andale Mono', ax=ax)

ax.set_title("Czechia\nHeatmap Passes 2023-2024", fontsize=18, color="w", fontfamily="Andale Mono", fontweight='bold', pad=8)
plt.savefig('Heatmap balltouches cze.png', dpi=750, bbox_inches='tight', facecolor='#000000')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch
from matplotlib import patches
from scipy.ndimage import gaussian_filter
from matplotlib.colors import LinearSegmentedColormap
import cmasher as cmr
import matplotlib.patheffects as path_effects

path_eff = [path_effects.Stroke(linewidth=3, foreground='black'),
            path_effects.Normal()]

df = pd.read_excel("/Users/marclambertes/Python/Czechia xT.xlsx")
df = df.loc[(df['contestantId']=='70tnqyqn871jwlk26gtjw7knm')].reset_index()
df = df.loc[(df['typeId'] == 1)].reset_index()

pitch = Pitch(pitch_type='opta', line_zorder=2, pitch_color='#1e4259')
fig, axs = pitch.grid(endnote_height=0.03, endnote_space=0,
                      title_height=0.08, title_space=0,
                      axis=False,
                      grid_height=0.84)
fig.set_facecolor('#1e4259')

pearl_earring_cmap = LinearSegmentedColormap.from_list("Pearl Earring - 10 colors",
                                                       ['#15242e', '#4393c4'], N=10)

# heatmap and labels
bin_statistic = pitch.bin_statistic_positional(df.x, df.y, statistic='count',
                                               positional='full', normalize=True)
pitch.heatmap_positional(bin_statistic, ax=axs['pitch'],
                         cmap=pearl_earring_cmap, edgecolors='#22312b')
labels = pitch.label_heatmap(bin_statistic, color='#f4edf0', fontsize=18,
                             ax=axs['pitch'], ha='center', va='center',
                             str_format='{:.0%}', path_effects=path_eff)

axs['pitch'].set_title("Czechia\nPassing - Heatmap UEFA Q 2023-2024", fontsize=18, color="w", fontfamily="Andale Mono", fontweight='bold', pad=8)
plt.savefig('Heatmap balltouches czechia JDP.png', dpi=750, bbox_inches='tight')

plt.show()
