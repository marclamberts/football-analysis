# %%
import matplotlib.pyplot as plt
from PIL import Image

#1 final third passes  #4 top shots     #7 final third passes
#2 shot assists         #5 Shot map      # shot assists
#3 heatmappass         #6 xT            # heatmap pass

# Load the PNG images
image1 = Image.open('xT home.png')
image2 = Image.open('Passnetwork Home.png')
image3 = Image.open('Passnetwork Away.png')
image4 = Image.open('xT away.png')
image5 = Image.open('Shotmap.png')
image6 = Image.open('FT Home.png')
image7 = Image.open('FT Away.png')
image8 = Image.open('Heatmap Home.png')
image9 = Image.open('Heatmap Away.png')



# Create a figure with four subplots
fig, axes = plt.subplots(4, 3, figsize=(20, 20))

for row in axes:
    for ax in row:
        ax.axis('off')

# Plot the images in the first row
axes[0, 0].imshow(image6)
axes[1, 0].imshow(image1)
axes[2, 0].imshow(image7)
axes[3, 0].imshow(image7)

# Plot the images in the second row
axes[0, 1].imshow(image2)
axes[1, 1].imshow(image5)
axes[2, 1].imshow(image3)
axes[3, 1].imshow(image3)

# Plot the images in the third row
axes[0, 2].imshow(image8)
axes[1, 2].imshow(image4)
axes[2, 2].imshow(image9)
axes[3, 2].imshow(image9)

# Add a title to the plot
fig.suptitle('West Brom - Leeds 1-0', fontsize=35, color='white')

# Add text below the plot
fig.text(0.5, 0.01, '@lambertsmarc | Data: Opta', ha='center', fontsize=12, color='white')




# Adjust the layout and spacing
plt.tight_layout()

# Save the plot to a file
plt.savefig('Subplots.png', dpi=500, bbox_inches='tight', facecolor='#242424')

# Display the plot
plt.show()

# %%
import tweepy

ACCESS_KEY = '1645091190021275648-2aF2QtfegDIPPb08gljYszydyF5Bpd'
ACCESS_SECRET = 'kzrnMAdMUq5vedvZ7ZqlczX0ojsL3MTUXsL8qzPpC59SA'
CONSUMER_KEY = '6b6qyiOt42ghG21wBZdvsaLSm'
CONSUMER_SECRET = 'osurgYS98Gh15814ixwlDPLqylQfxma0UDEvE3W586ciMSvDv4'


api = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAHRGnwEAAAAAdqLgF05rZymYirRnjePMyAjOiu4%3DV0cKStwsm5X4ml8rMj2hi3tmaTJnnblH24ijuUcCggl6zjriGB',
                    access_token=ACCESS_KEY,
                    access_token_secret=ACCESS_SECRET,
                    consumer_key=CONSUMER_KEY,
                    consumer_secret=CONSUMER_SECRET)

auth = tweepy.OAuth1UserHandler(
    CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET
)
oldapi = tweepy.API(auth)
media1 = oldapi.media_upload("Subplots.png")


api.create_tweet(text='Chelsea - West Ham United 2-0\nDashboard\nWSL 2023-2024',media_ids=[media1.media_id])
# Out:
# Response(data={'edit_history_tweet_ids': ['1713494676412527092'], 'id': '1713494676412527092', 'text': 'Chelsea - West Ham United 2-0\nDashboard\nWSL 2023-2024 https://t.co/gBnNiNgy6t'}, includes={}, errors=[], meta={})

# %%
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.gridspec as gridspec

# Load the PNG images
image1 = Image.open(r'/Users/marclambertes/Python/Shotmap 2223.png')
image2 = Image.open(r'/Users/marclambertes/Python/Passnetwork Home.png')
image3 = Image.open(r'/Users/marclambertes/Python/Passnetwork Away.png')
image4 = Image.open(r'/Users/marclambertes/Python/xT home.png')
image5 = Image.open(r'/Users/marclambertes/Python/xG flow facup - .png')
image6 = Image.open(r'/Users/marclambertes/Python/xT away.png')

# Create a figure with custom subplot layout
fig = plt.figure(figsize=(12, 16))
gs = gridspec.GridSpec(2, 3, width_ratios=[1, 2, 1], hspace=0.1)  # Adjust hspace

# Plot the images
axes = [
    fig.add_subplot(gs[0, 0]), fig.add_subplot(gs[0, 1]), fig.add_subplot(gs[0, 2]),
    fig.add_subplot(gs[1, 0]), fig.add_subplot(gs[1, 1]), fig.add_subplot(gs[1, 2])
]

for ax in axes:
    ax.axis('off')

# Plot the images in the first row
axes[1].imshow(image1)
axes[0].imshow(image2)
axes[2].imshow(image3)

# Plot the images in the second row
axes[3].imshow(image4)
axes[4].imshow(image5)
axes[5].imshow(image6)

# Make the upper middle subplot bigger
axes[1].set_position([0.27, 0.38, 0.46, 0.6])  # [left, bottom, width, height]

# Add a title to the plot
# fig.suptitle('Nigeria - Canada 0-0', fontsize=35, color='white')

# Add text below the plot
# fig.text(0.5, 0.01, '@ShePlotsFC | Data: Opta', ha='center', fontsize=12, color='white')

# Adjust the layout and spacing
plt.tight_layout()

# Save the plot to a file
plt.savefig('Subplots.png', dpi=500, bbox_inches='tight', facecolor='#242424')

# Display the plot
plt.show()
# Out:
# /var/folders/68/mhmqcpdn52943pyql2n4wj440000gn/T/ipykernel_44864/3818660425.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
